# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import RobustScaler, LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
pd.set_option('display.max_columns', None)

# %%
df=pd.read_csv('all_df.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2867154 entries, 0 to 2867153
# Data columns (total 71 columns):
# Unnamed: 0          int64
# px                  float64
# pz                  float64
# start_speed         float64
# end_speed           float64
# spin_rate           float64
# spin_dir            float64
# break_angle         float64
# break_length        float64
# break_y             float64
# ax                  float64
# ay                  float64
# az                  float64
# sz_bot              float64
# sz_top              float64
# type_confidence     float64
# vx0                 float64
# vy0                 float64
# vz0                 float64
# x                   float64
# x0                  float64
# y                   float64
# y0                  float64
# z0                  float64
# pfx_x               float64
# pfx_z               float64
# nasty               float64
# zone                float64
# code                object
# type                object
# pitch_type          object
# event_num           int64
# b_score             float64
# ab_id               int64
# b_count             float64
# s_count             float64
# outs                float64
# pitch_num           float64
# on_1b               float64
# on_2b               float64
# on_3b               float64
# batter_id           int64
# event               object
# g_id                int64
# inning              int64
# o                   int64
# p_score             int64
# p_throws            object
# pitcher_id          int64
# stand               object
# top                 bool
# attendance          int64
# away_final_score    int64
# away_team           object
# date                object
# elapsed_time        int64
# home_final_score    int64
# home_team           object
# start_time          object
# umpire_1B           object
# umpire_2B           object
# umpire_3B           object
# umpire_HP           object
# venue_name          object
# weather             object
# wind                object
# delay               int64
# Batters Name        object
# first_name          object
# last_name           object
# Pitchers Name       object
# dtypes: bool(1), float64(35), int64(14), object(21)
# memory usage: 1.5+ GB

# %%
df.describe()
# Out:
#          Unnamed: 0            px            pz   start_speed     end_speed  \
# count  2.867154e+06  2.852965e+06  2.852965e+06  2.853040e+06  2.853040e+06
# mean   1.433576e+06  6.572502e-03  2.254962e+00  8.838124e+01  8.136274e+01
# std    8.276762e+05  8.927490e-01  9.463968e-01  6.015540e+00  5.364057e+00
# min    0.000000e+00 -1.054333e+01 -5.183664e+00  3.390000e+01  3.240000e+01
# 25%    7.167882e+05 -5.908243e-01  1.650000e+00  8.430000e+01  7.790000e+01
# 50%    1.433576e+06  1.300000e-02  2.259000e+00  8.970000e+01  8.250000e+01
# 75%    2.150365e+06  6.090000e-01  2.863000e+00  9.300000e+01  8.540000e+01
# max    2.867153e+06  1.295291e+01  1.488624e+01  1.050000e+02  9.690000e+01
#
#           spin_rate      spin_dir   break_angle  break_length       break_y  \
# count  2.852965e+06  2.852965e+06  2.852965e+06  2.852965e+06  2.852965e+06
# mean   1.731173e+03  1.802308e+02  5.848084e+00  6.601459e+00  2.381685e+01
# std    6.827521e+02  6.742859e+01  2.443621e+01  1.331708e+02  6.446540e-02
# min    1.214000e+00 -2.000000e-03 -9.000000e+01  1.000000e-01  2.330000e+01
# 25%    1.238745e+03  1.371540e+02 -1.190000e+01  4.300000e+00  2.380000e+01
# 50%    1.866322e+03  1.958850e+02  6.800000e+00  6.000000e+00  2.380000e+01
# 75%    2.247564e+03  2.252340e+02  2.700000e+01  8.000000e+00  2.390000e+01
# max    6.539259e+03  3.600010e+02  2.694000e+02  2.248893e+05  3.640000e+01
#
#        ...          g_id        inning             o       p_score  \
# count  ...  2.867154e+06  2.867154e+06  2.867154e+06  2.867154e+06
# mean   ...  2.016525e+08  5.006868e+00  1.673523e+00  2.293307e+00
# std    ...  1.115803e+05  2.669174e+00  9.528891e-01  2.633267e+00
# min    ...  2.015000e+08  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    ...  2.016000e+08  3.000000e+00  1.000000e+00  0.000000e+00
# 50%    ...  2.017001e+08  5.000000e+00  2.000000e+00  1.000000e+00
# 75%    ...  2.018000e+08  7.000000e+00  2.000000e+00  4.000000e+00
# max    ...  2.018024e+08  1.900000e+01  3.000000e+00  2.500000e+01
#
#          pitcher_id    attendance  away_final_score  elapsed_time  \
# count  2.867154e+06  2.867154e+06      2.867154e+06  2.867154e+06
# mean   5.274988e+05  2.975219e+04      4.562997e+00  1.881358e+02
# std    7.752456e+04  1.020782e+04      3.212747e+00  2.934178e+01
# min    1.125260e+05  0.000000e+00      0.000000e+00  7.500000e+01
# 25%    4.621360e+05  2.179200e+04      2.000000e+00  1.700000e+02
# 50%    5.416400e+05  3.011200e+04      4.000000e+00  1.840000e+02
# 75%    5.928360e+05  3.789800e+04      6.000000e+00  2.020000e+02
# max    6.736330e+05  5.631000e+04      2.400000e+01  4.090000e+02
#
#        home_final_score         delay
# count      2.867154e+06  2.867154e+06
# mean       4.639906e+00  3.905359e+00
# std        3.206800e+00  2.751812e+01
# min        0.000000e+00  0.000000e+00
# 25%        2.000000e+00  0.000000e+00
# 50%        4.000000e+00  0.000000e+00
# 75%        6.000000e+00  0.000000e+00
# max        2.500000e+01  1.860000e+03
#
# [8 rows x 49 columns]

# %% [markdown]
# ##### will get rid of unneccesary data for a new Dataframe, divide data by seasons since there is almost 3 million data points
